# %%
import numpy as np
import pandas as pd

# %%
flats=pd.read_csv('dataset/flats_cleaned.csv')
houses=pd.read_csv('dataset/house_cleaned.csv')

# %%
df=pd.concat([flats,houses],ignore_index=True)

# %%
df=df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                      property_name property_type                   society  \
# 0  3 BHK Flat in Sector 66 Gurgaon          flat  emaar mgf the palm drive
# 1  2 BHK Flat in Sector 62 Gurgaon          flat           emaar digihomes
# 2  3 BHK Flat in Sector 65 Gurgaon          flat               m3m heights
# 3    3 BHK Flat in Nirvana Country          flat           the close south
# 4  3 BHK Flat in Sector 33 Gurgaon          flat    unitech the residences
#
#    price  price_per_sqft    area  \
# 0   3.98         18090.0  2200.0
# 1   2.15         14257.0  1508.0
# 2   2.44         13300.0  1835.0
# 3   3.10         12444.0  2491.0
# 4   1.55          9872.0  1570.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 2200(204.39 sq.m.)        3         4
# 1                    Carpet area: 1508 (140.1 sq.m.)        2         2
# 2             Super Built up area 1828(169.83 sq.m.)        3         3
# 3  Super Built up area 2491(231.42 sq.m.)Built Up...        3         4
# 4             Super Built up area 1570(145.86 sq.m.)        3         4
#
#   balcony additionalRoom                                    address  floorNum  \
# 0      3+   servant room        Sector 66 Gurgaon, Gurgaon, Haryana       2.0
# 1       3  not available  3301, Sector 62 Gurgaon, Gurgaon, Haryana      31.0
# 2       2  not available        Sector 65 Gurgaon, Gurgaon, Haryana       7.0
# 3      3+   servant room     4th, Nirvana Country, Gurgaon, Haryana       4.0
# 4       1   servant room   101, Sector 33 Gurgaon, Gurgaon, Haryana       1.0
#
#        facing       agePossession  \
# 0  South-East    5 to 10 Year Old
# 1         NaN  Under Construction
# 2         NaN            May 2024
# 3  North-East    5 to 10 Year Old
# 4       South     1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
# 1  ['Sector 55-56 Metro Station', 'Omaxe Gurgaon ...
# 2  ['Rapid Metro Sector 56', 'M3m 65th Avenue Mal...
# 3  ['Fresco Market', 'Emerald Plaza', 'Tagore Pub...
# 4  ['Huda Metro Station', 'Raheja Mall', 'Delhi G...
#
#                                          description  \
# 0  Beautiful two side open property, facing kids ...
# 1  This is your chance to own a 2 bhk residential...
# 2  Gurgaon sector 65 is a prime location in gurga...
# 3  The close south is one of gurgaon's most sough...
# 4  Central garden full view.\nGood ventilation.\n...
#
#                                       furnishDetails  \
# 0  ['6 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 1                                                NaN
# 2                                                 []
# 3  ['4 Wardrobe', '8 Fan', '1 Exhaust Fan', '3 Ge...
# 4  ['7 Fan', '7 Light', '3 Wardrobe', 'No AC', 'N...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Power Back-up', 'In...
# 1  ['Security / Fire Alarm', 'Intercom Facility',...
# 2  ['Power Back-up', 'Intercom Facility', 'Lift(s...
# 3  ['Centrally Air Conditioned', 'Water purifier'...
# 4  ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction4.5 out ...
# 1  ['Connectivity4 out of 5', 'Lifestyle5 out of ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3  ['Green Area5 out of 5', 'Construction4.5 out ...
# 4  ['Green Area5 out of 5', 'Amenities3 out of 5'...

# %%
df.to_csv('gurgaon_properties.csv',index=False)
