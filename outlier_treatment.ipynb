# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('dataset/gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                   society     sector  price  price_per_sqft  \
# 0          flat  emaar mgf the palm drive  sector 66   3.98         18090.0
# 1          flat           emaar digihomes  sector 62   2.15         14257.0
# 2          flat               m3m heights  sector 65   2.44         13300.0
# 3          flat           the close south  sector 50   3.10         12444.0
# 4          flat    unitech the residences  sector 33   1.55          9872.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2200.0             Super Built up area 2200(204.39 sq.m.)        3
# 1  1508.0                    Carpet area: 1508 (140.1 sq.m.)        2
# 2  1835.0             Super Built up area 1828(169.83 sq.m.)        3
# 3  2491.0  Super Built up area 2491(231.42 sq.m.)Built Up...        3
# 4  1570.0             Super Built up area 1570(145.86 sq.m.)        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
sns.displot(df['price'],kde=True)

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
Q1=df['price'].quantile(0.25)
Q3=df['price'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

outliers=df[(df['price']<lower_bound)|(df['price']>upper_bound)]
num_outliers=outliers.shape[0]
outliers_price_stats=outliers['price'].describe()
num_outliers,outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
sns.displot(df['price_per_sqft'])

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.histplot(df['price_per_sqft'], kde=True)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society      sector  price  \
# 134          house                dlf city plots   sector 26  26.00
# 1106         house                  malibu towne   sector 47   8.50
# 1319         house        emaar the palm springs   sector 54  24.00
# 1329         house        emaar the palm springs   sector 54  14.00
# 1843         house                   independent   sector 25  16.00
# 1948         house                           nul   sector 28  12.50
# 2040         house                unitech escape   sector 50  10.80
# 2625          flat                unitech vistas   sector 70   9.00
# 2996         house                   independent   sector 26  26.00
# 3129         house            cloudnine cottages  sohna road   5.50
# 3237         house            emaar mgf marbella   sector 66  18.00
# 3695         house  project housing board colony   sector 31   8.00
# 3782         house                   independent   sector 26  14.75
#
# ...

# %%
df=df[df['price_per_sqft']<=50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
sns.histplot(df['area'],kde=True)
# Out:
# <Axes: xlabel='area', ylabel='Count'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df=df[df['area']<100000]

# %%
sns.histplot(df['area'],kde=True)
# Out:
# <Axes: xlabel='area', ylabel='Count'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area']>10000].sort_values('area',ascending=False)
# 3012,2614,1316,3435,2733,421,73,1916,1024
# Out:
#      property_type                    society      sector  price  \
# 3012         house                independent   sector 26  18.40
# 3407         house  ganpati heights apartment   sector 13   1.25
# 2614          flat                 rof ananda   sector 95   0.38
# 1316          flat                 rof ananda   sector 95   0.38
# 3477         house      dlf city plot phase 4   sector 28  13.00
# 3435          flat              pyramid elite   sector 86   0.46
# 2733          flat                 rof ananda   sector 95   0.33
# 421           flat      signature the serenas  sohna road   0.28
# 2975         house                independent   sector 25   7.30
# 73            flat            ramsons kshitij   sector 95   0.24
# 1916          flat                 rof ananda   sector 95   0.21
# 3382         house                independent   sector 57   6.25
# 1122         house                independent   sector 43   5.50
# ...

# %%
df.drop(index=[3012,2614,1316,3435,2733,421,73,1916,1024],inplace=True)

# %%
df[df['area']>10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 3407         house  ganpati heights apartment   sector 13   1.25
# 3477         house      dlf city plot phase 4   sector 28  13.00
# 2975         house                independent   sector 25   7.30
# 3382         house                independent   sector 57   6.25
# 1122         house                independent   sector 43   5.50
# 770           flat                 godrej air   sector 85   2.50
# 2270         house       unitech aspen greens   sector 50   6.95
# 3491          flat                godrej icon  sector 88a   1.75
# 3017         house                independent   sector 43  27.50
# 1518          flat             m3m golfestate   sector 65  13.20
# 257          house                independent  sohna road   5.50
#
#       price_per_sqft     area  \
# 3407           151.0  82781.0
# 3477          1992.0  65261.0
# 2975          1560.0  46795.0
# 3382          2778.0  22498.0
# ...

# %%
df.loc[3407,'area'] = 115*9
df.loc[3477,'area'] = 7250
df.loc[2975,'area'] = 5800
df.loc[3382,'area'] = 2660
df.loc[1122,'area'] = 2850
df.loc[770,'area'] = 1812
df.loc[2270,'area'] = 2160
df.loc[3491,'area'] = 1175

# %%
sns.displot(df['area'],kde=True)

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1950.357005
# std       1215.707897
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %%
sns.histplot(df['bedRoom'],kde=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='Count'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom']>10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 650          house                  independent   sector 54   5.00
# 153          house                  independent   sector 43   4.50
# 122          house                  independent  sector 17a   3.87
# 3565         house                  independent  sector 17a   3.93
# 1619         house                  independent   sector 54   5.50
# 3178         house                private house   sector 55   7.05
# 3730         house                  independent   sector 11   4.50
# 3255         house                  independent   sector 40  12.00
# 2564         house               dlf city plots   sector 26  20.00
# 1479         house                  independent   sector 55   9.19
# 2319         house       luxury dlf city floors   sector 26  20.00
# 1238         house                  independent   sector 43  13.50
# 210          house                  independent   sector 56  12.39
# ...

# %%
df=df[df['bedRoom']<=10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.histplot(df['bedRoom'],kde=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='Count'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.203735
# std         1.393968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %%
sns.histplot(df['bathroom'],kde=True)
# Out:
# <Axes: xlabel='bathroom', ylabel='Count'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom']>10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 466          house  adani brahma samsara  sector 60  18.02         28200.0
# 822          house           independent  sector 39   7.00         10000.0
# 3211         house           independent  sector 24  11.00         28902.0
#
#         area                                       areaWithType  bedRoom  \
# 466   6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 822   7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 3211  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 466         12      3+       3.0  North-East  Relatively New
# 822         11      3+       4.0  South-East  Relatively New
# 3211        11      3+       3.0        East    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
df.head()
# Out:
#   property_type                   society     sector  price  price_per_sqft  \
# 0          flat  emaar mgf the palm drive  sector 66   3.98         18090.0
# 1          flat           emaar digihomes  sector 62   2.15         14257.0
# 2          flat               m3m heights  sector 65   2.44         13300.0
# 3          flat           the close south  sector 50   3.10         12444.0
# 4          flat    unitech the residences  sector 33   1.55          9872.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2200.0             Super Built up area 2200(204.39 sq.m.)        3
# 1  1508.0                    Carpet area: 1508 (140.1 sq.m.)        2
# 2  1835.0             Super Built up area 1828(169.83 sq.m.)        3
# 3  2491.0  Super Built up area 2491(231.42 sq.m.)Built Up...        3
# 4  1570.0             Super Built up area 1570(145.86 sq.m.)        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
sns.histplot(df['super_built_up_area'],kde=True)
# Out:
# <Axes: xlabel='super_built_up_area', ylabel='Count'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area']>6000]
# Out:
#      property_type                      society       sector  price  \
# 2139          flat       krrish provence estate  gwal pahari    7.5
# 3050          flat  bestech park view grand spa    sector 81    4.7
#
#       price_per_sqft     area                             areaWithType  \
# 2139          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
# 3050          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 2139        5         6      3+      23.0  North-East  Relatively New
# 3050        4         4      3+      19.0       North  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 2139              10000.0            NaN          NaN           0
# 3050               6926.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %%
sns.histplot(df['built_up_area'],kde=True)
# Out:
# <Axes: xlabel='built_up_area', ylabel='Count'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area']>10000]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []

# %%
sns.histplot(df['carpet_area'],kde=True)
# Out:
# <Axes: xlabel='carpet_area', ylabel='Count'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area']>10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 770           flat      godrej air  sector 85    2.5          1379.0   1812.0
# 1518          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 770   Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
# 1518  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 770   North-East  Under Construction                  NaN            NaN
# 1518       North      Moderately Old                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 770       18122.0           1             0           0           1       1
# 1518      11000.0           0             1           0           0       0
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[770,'carpet_area']=1812

# %%
df[df['carpet_area']>10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 1518          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1518  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#      facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 1518  North  Moderately Old                  NaN            NaN      11000.0
#
#       study room  servant room  store room  pooja room  others  \
# 1518           0             1           0           0       0
#
#       furnishing_type  luxury_score
# 1518                0            60

# %%
sns.histplot(df['luxury_score'],kde=True)
# Out:
# <Axes: xlabel='luxury_score', ylabel='Count'>

# %%
sns.boxplot(x=df['luxury_score'])
# Out:
# <Axes: xlabel='luxury_score'>

# %%
df.shape
# Out:
# (3588, 23)

# %%
df['price_per_sqft']=round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type                   society     sector  price  price_per_sqft  \
# 0          flat  emaar mgf the palm drive  sector 66   3.98         18091.0
# 1          flat           emaar digihomes  sector 62   2.15         14257.0
# 2          flat               m3m heights  sector 65   2.44         13297.0
# 3          flat           the close south  sector 50   3.10         12445.0
# 4          flat    unitech the residences  sector 33   1.55          9873.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2200.0             Super Built up area 2200(204.39 sq.m.)        3
# 1  1508.0                    Carpet area: 1508 (140.1 sq.m.)        2
# 2  1835.0             Super Built up area 1828(169.83 sq.m.)        3
# 3  2491.0  Super Built up area 2491(231.42 sq.m.)Built Up...        3
# 4  1570.0             Super Built up area 1570(145.86 sq.m.)        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
sns.histplot(df['price_per_sqft'],kde=True)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>42000]
# Out:
#      property_type                       society      sector  price  \
# 312          house  sushant lok 1 builder floors   sector 43   13.0
# 747          house                dlf city plots   sector 26   19.0
# 761          house                   independent   sector 26   19.0
# 931          house                   independent   sector 43    9.5
# 1102         house                   independent  sector 105    9.9
# 1610         house                   independent   sector 25   13.0
# 2115         house                   independent   sector 28   12.0
# 2154         house                   independent   sector 26   20.0
# 3455         house                   independent   sector 55    5.0
#
#       price_per_sqft    area  \
# 312          48148.0  2700.0
# 747          42054.0  4518.0
# 761          42222.0  4500.0
# 931          42222.0  2250.0
# 1102         49500.0  2000.0
# 1610         45710.0  2844.0
# 2115         42194.0  2844.0
# 2154         44444.0  4500.0
# ...

# %%
x=df[df['price_per_sqft']<=20000]
(x['area']/x['bedRoom']).quantile(0.02)
# Out:
# np.float64(183.33333333333334)

# %%
df[(df['area']/df['bedRoom'])<183]
# Out:
#      property_type             society      sector  price  price_per_sqft  \
# 30           house      not applicable    sector 4   0.75         11719.0
# 121          house         independent    sector 8   0.49         11239.0
# 124          house         independent    sector 2   3.65         23443.0
# 302          house         independent    sector 4   0.60         11696.0
# 347          house         independent   sector 38   2.10         23333.0
# ...            ...                 ...         ...    ...             ...
# 3557         house     sheetla enclave    sector 5   0.96         10000.0
# 3617         house         independent   sector 21   0.60          6173.0
# 3669         house  sai kripa floors 5   sector 11   0.90         11250.0
# 3795         house         independent  sector 105   0.60         13333.0
# 3802         house         independent    sector 4   0.92         15257.0
#
#         area                      areaWithType  bedRoom  bathroom balcony  \
# ...

# %%
x=df[df['price_per_sqft']<=20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# np.float64(250.5)

# %%
df[df['area']/df['bedRoom']<250].sample(5)
# Out:
#      property_type      society     sector  price  price_per_sqft    area  \
# 881          house     ss omnia  sector 86   0.42          9333.0   450.0
# 1503         house  independent   sector 3   0.92         15257.0   603.0
# 330          house  independent  sector 12   6.00         35088.0  1710.0
# 2266          flat  tulip lemon  sector 69   0.62         12863.0   482.0
# 3217         house  independent  sector 47   5.15         26615.0  1935.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 881                            Plot area 50(4.65 sq.m.)        5         3
# 1503                   Built Up area: 603 (56.02 sq.m.)        4         1
# 330   Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...        9         6
# 2266                     Carpet area: 482 (44.78 sq.m.)        2         2
# 3217                        Plot area 215(179.77 sq.m.)        9         9
#
# ...

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df['area_room_ratio']=df['area']/df['bedRoom']

# %%
(df[df['area_room_ratio']<250])['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     47
# 3     33
# 5     28
# 6     17
# 4     17
# 9     15
# 8     12
# 7      8
# 10     8
# Name: count, dtype: int64

# %%
df=df[df['area_room_ratio']>100]

# %%
outliers_df=df[(df['area_room_ratio']<250)& (df['bedRoom']>3)]

# %%
outliers_df['bedRoom']=round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio']=df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom']>4)]
# Out:
#      property_type               society      sector  price  price_per_sqft  \
# 355          house           independent  sector 105   1.10         12222.0
# 510          house           independent     manesar   0.80          6667.0
# 808          house           independent    sector 2   0.98          9074.0
# 1053         house           independent    sector 7   1.16         11717.0
# 1244         house           independent    sector 3   0.85          9444.0
# 1347         house           independent     manesar   1.10          6173.0
# 1544         house           independent   sector 11   3.50         15556.0
# 2450         house              shivpuri    sector 7   2.80         12444.0
# 2559         house           independent    sector 3   1.10         10000.0
# 2874         house           independent   sector 12   2.50         13889.0
# 2962         house  bhim nagar, sector 6    sector 6   0.85         14096.0
# ...

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom']>4)].shape
# Out:
# (13, 24)

# %%
df.shape
# Out:
# (3568, 24)

# %%
df=df[~((df['area_room_ratio']<250) & (df['bedRoom']>4))]

# %%
df.shape
# Out:
# (3555, 24)

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df.to_csv('dataset/gurgaon_properties_outlier_treated.csv',index=False)
