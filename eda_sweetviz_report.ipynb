# %%
pip install sweetviz
# Out:
# ...
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    ---- ----------------------------------- 1.8/15.1 MB 11.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.5/15.1 MB 11.6 MB/s eta 0:00:01
#    ------------------ --------------------- 6.8/15.1 MB 11.7 MB/s eta 0:00:01
#    ------------------------ --------------- 9.4/15.1 MB 11.7 MB/s eta 0:00:01
#    ------------------------------- -------- 11.8/15.1 MB 11.8 MB/s eta 0:00:01
#    -------------------------------------- - 14.4/15.1 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.1/15.1 MB 11.3 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ------------- -------------------------- 1/3 [importlib_resources]
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('dataset/gurgaon_properties_cleaned_v2.csv')

# %%
import sweetviz as sv

report = sv.analyze(df)

report.show_html(filepath="output_report.html", open_browser=False)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# ...

# %%
pip install dtale
# Out:
# ...
#   Using cached dtale-3.22.0-py2.py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached lz4-4.4.5-cp314-cp314-win_amd64.whl.metadata (3.9 kB)
# ...
#   Using cached dash-4.4.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached dash_bootstrap_components-2.0.4-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached flask_compress-1.25-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# ...
#   Using cached kaleido-1.4.0-py3-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached pkginfo-1.13-py3-none-any.whl.metadata (13 kB)
# ...

# %%
import dtale
d = dtale.show(df)

d.open_browser()
